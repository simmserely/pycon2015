# %%
# %matplotlib inline
import pandas as pd

# %%
from IPython.core.display import HTML
css = open('style-table.css').read() + open('style-notebook.css').read()
HTML('<style>{}</style>'.format(css))
# Out:
# <style>body {
#     margin: 0;
#     font-family: Helvetica;
# }
# table.dataframe {
#     border-collapse: collapse;
#     border: none;
# }
# table.dataframe tr {
#     border: none;
# }
# table.dataframe td, table.dataframe th {
#     margin: 0;
#     border: 1px solid white;
#     padding-left: 0.25em;
#     padding-right: 0.25em;
# }
# table.dataframe th:not(:empty) {
#     background-color: #fec;
#     text-align: left;
#     font-weight: normal;
# }
# table.dataframe tr:nth-child(2) th:empty {
#     border-left: none;
#     border-right: 1px dashed #888;
# }
# table.dataframe td {
#     border: 2px solid #ccf;
#     background-color: #f4f4ff;
# }
# h3 {
#     color: white;
#     background-color: black;
#     padding: 0.5em;
# }
# </style>

# %%
titles = pd.read_csv('data/titles.csv', index_col=None)
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2   The Spider and the Fly  1949
# 3                  Country  2000
# 4          The Golden Note  2017

# %%
cast = pd.read_csv('data/cast.csv', index_col=None)
cast.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
len(titles)
# Out:
# 244914

# %%
h = titles.tail(8)
# operations
h
# Out:
#                         title  year
# 244906         Hu tu nu si ji  1982
# 244907  Nobody Waved Good-bye  1964
# 244908     Alexander Jamieson  2017
# 244909                  E yue  2005
# 244910           Lakota Girls  2015
# 244911         Kroniki domowe  1997
# 244912   Awakening the Zodiac  2017
# 244913         American Satan  2017

# %%
h['year'] // 10 * 10
# Out:
# 244906    1980
# 244907    1960
# 244908    2010
# 244909    2000
# 244910    2010
# 244911    1990
# 244912    2010
# 244913    2010
# Name: year, dtype: int64

# %%
h.year > 1985
# Out:
# 244906    False
# 244907    False
# 244908     True
# 244909     True
# 244910     True
# 244911     True
# 244912     True
# 244913     True
# Name: year, dtype: bool

# %%
h[h['year'] > 1985]
# Out:
#                        title  year
# 244908    Alexander Jamieson  2017
# 244909                 E yue  2005
# 244910          Lakota Girls  2015
# 244911        Kroniki domowe  1997
# 244912  Awakening the Zodiac  2017
# 244913        American Satan  2017

# %%
h[(h.year < 1985) | (h.year >= 1990)] # always use brackets w/ & in pandas
# the & in this case defaults to running on numbers first so it will try to boolean 1985 and h.year otherwise
#'''If you want "or" use |'''
# Out:
#                         title  year
# 244906         Hu tu nu si ji  1982
# 244907  Nobody Waved Good-bye  1964
# 244908     Alexander Jamieson  2017
# 244909                  E yue  2005
# 244910           Lakota Girls  2015
# 244911         Kroniki domowe  1997
# 244912   Awakening the Zodiac  2017
# 244913         American Satan  2017

# %%
t = titles
t[t.title == 'Macbeth'].sort_values('year')
# Out:
#           title  year
# 4407    Macbeth  1913
# 71411   Macbeth  1916
# 149536  Macbeth  1948
# 215678  Macbeth  1987
# 17973   Macbeth  1997
# 166888  Macbeth  1998
# 91697   Macbeth  2003
# 140102  Macbeth  2004
# 58888   Macbeth  2006
# 159718  Macbeth  2009
# 150816  Macbeth  2012
# 12245   Macbeth  2013
# 110636  Macbeth  2014
# 133221  Macbeth  2015
# 195292  Macbeth  2017
# 47807   Macbeth  2018

# %%
t = titles
t[t.title == 'Macbeth'].sort_values('year').head()
# Out:
#           title  year
# 4407    Macbeth  1913
# 71411   Macbeth  1916
# 149536  Macbeth  1948
# 215678  Macbeth  1987
# 17973   Macbeth  1997

# %%
t = titles
t[t.title == 'Macbeth'].sort_values('year').tail() # .sort() has been deprecated
# Out:
#           title  year
# 12245   Macbeth  2013
# 110636  Macbeth  2014
# 133221  Macbeth  2015
# 195292  Macbeth  2017
# 47807   Macbeth  2018

# %%
t.year.sort_values().head(10) #.order has been deprecated
# Out:
# 187327    1894
# 226857    1898
# 131240    1899
# 193369    1900
# 100010    1900
# 21801     1900
# 198136    1900
# 14336     1900
# 220306    1903
# 71802     1905
# Name: year, dtype: int64

# %%
cast.head().n.notnull() # this way does not give you a dataframe
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# Name: n, dtype: bool

# %%
ch = cast.head()
chnn = ch[ch.n.notnull()] #this way gives you a dataframe (notice it only gives records 0,1,2 b/c they're true)
chnn
# Out:
#                  title  year      name   type        character     n
# 0       Closet Monster  2015  Buffy #1  actor          Buffy 4  31.0
# 1      Suuri illusioni  1985    Homo $  actor           Guests  22.0
# 2  Battle of the Sexes  2017   $hutter  actor  Bobby Riggs Fan  10.0

# %%
c = titles
c[c.title.str.startswith('Hamlet')]
# Out:
#                                 title  year
# 2371             Hamlet Demonstration  2011
# 6320                           Hamlet  1948
# 9061                      Hamlet (II)  2005
# 9367                      Hamlet (II)  2015
# 15984                  Hamlet Unbound  2012
# 18345       Hamlet, Prince of Denmark  1997
# 28356                     Hamlet (II)  2007
# 28692                  Hamlet/Horatio  2017
# 31546                     Hamlet (II)  2017
# 39215                        Hamlet_X  2003
# 41403        Hamlet, Son of a Kingpin  2015
# 47163                    Hamlet (III)  2007
# 49308                          Hamlet  1910
# 52004                          Hamlet  2017
# 77194                          Hamlet  1954
# 77870                  Hamlet's Ghost  2015
# 79072                          Hamlet  2015
# 83215   Hamlet: The Fall of a Sparrow  2018
# 83372                        Hamlet X  2004
# 97017                          Hamlet  1976
# ...

# %%
titles.year.value_counts().sort_index().plot()

# %%
c = cast
c = c[c.character == 'Kermit the Frog']
c.head()
c.plot (x='year', y='n', kind='scatter')

# %%
c.head()[['year', 'n']]
# Out:
#         year     n
# 982460  1981  18.0
# 982461  1985   2.0
# 982466  1981   1.0
# 982474  1979   1.0
# 982481  1984   1.0

# %%
len(cast)
# Out:
# 3786176

# %%
# %%time
cast[cast.title == 'Sleuth']
# Out:
# CPU times: user 667 ms, sys: 341 ms, total: 1.01 s
# Wall time: 1.07 s
#           title  year                 name     type  \
# 260242   Sleuth  2007      Kenneth Branagh    actor
# 326773   Sleuth  1972        Michael Caine    actor
# 326774   Sleuth  2007        Michael Caine    actor
# 373876   Sleuth  1972       Alec Cawthorne    actor
# 373877   Sleuth  2007  Alec (II) Cawthorne    actor
# 1293634  Sleuth  2007             Jude Law    actor
# 1448690  Sleuth  1972         Teddy Martin    actor
# 1465483  Sleuth  1972   John (II) Matthews    actor
# 1705394  Sleuth  1972     Laurence Olivier    actor
# 1805907  Sleuth  2007        Harold Pinter    actor
# 2724552  Sleuth  2007    Eve (II) Channing  actress
# 2724553  Sleuth  1972   Eve (III) Channing  actress
# 3370424  Sleuth  2007    Carmel O'Sullivan  actress
#
#                           character    n
# 260242            Other Man on T.V.  NaN
# 326773                  Milo Tindle  2.0
# ...

# %%
c = cast.set_index(['title'])
c.head()
# Out:
#                       year      name   type                character     n
# title
# Closet Monster        2015  Buffy #1  actor                  Buffy 4  31.0
# Suuri illusioni       1985    Homo $  actor                   Guests  22.0
# Battle of the Sexes   2017   $hutter  actor          Bobby Riggs Fan  10.0
# Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# Steve Jobs            2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
c = cast.set_index(['title', 'year']).sort_index() #indexing helps you most when it's sorted
c.head()
# Out:
#                                     name   type               character     n
# title            year
# #1 Serial Killer 2013      Michael Alton  actor       Detective Roberts  17.0
#                  2013         Aaron Aoki  actor      Plastic Bag Victim  21.0
#                  2013  Zachary (X) Brown  actor  Africian American Teen  18.0
#                  2013     Yvis Cannavale  actor            Homeless Man  25.0
#                  2013      Patrick Chien  actor          Cleaver Victim  22.0

# %%
# %%time
#c.loc['Sleuth'].loc[1972] #much faster after investing time sorting
c.loc[('Sleuth', 1972)]
# Out:
# CPU times: user 2.11 ms, sys: 1.39 ms, total: 3.5 ms
# Wall time: 5.09 ms
#                            name     type                   character    n
# title  year
# Sleuth 1972       Michael Caine    actor                 Milo Tindle  2.0
#        1972      Alec Cawthorne    actor           Inspector Doppler  3.0
#        1972        Teddy Martin    actor      Police Constable Higgs  6.0
#        1972  John (II) Matthews    actor  Detective Sergeant Tarrant  4.0
#        1972    Laurence Olivier    actor                 Andrew Wyke  1.0
#        1972  Eve (III) Channing  actress             Marguerite Wyke  5.0

# %%
c.loc[('Sleuth', 1972)]
# Out:
#                            name     type                   character    n
# title  year
# Sleuth 1972       Michael Caine    actor                 Milo Tindle  2.0
#        1972      Alec Cawthorne    actor           Inspector Doppler  3.0
#        1972        Teddy Martin    actor      Police Constable Higgs  6.0
#        1972  John (II) Matthews    actor  Detective Sergeant Tarrant  4.0
#        1972    Laurence Olivier    actor                 Andrew Wyke  1.0
#        1972  Eve (III) Channing  actress             Marguerite Wyke  5.0

# %%
c.loc[('Sleuth', 1972)].reset_index(['year', 'title'])
# Out:
#     title  year                name     type                   character    n
# 0  Sleuth  1972       Michael Caine    actor                 Milo Tindle  2.0
# 1  Sleuth  1972      Alec Cawthorne    actor           Inspector Doppler  3.0
# 2  Sleuth  1972        Teddy Martin    actor      Police Constable Higgs  6.0
# 3  Sleuth  1972  John (II) Matthews    actor  Detective Sergeant Tarrant  4.0
# 4  Sleuth  1972    Laurence Olivier    actor                 Andrew Wyke  1.0
# 5  Sleuth  1972  Eve (III) Channing  actress             Marguerite Wyke  5.0

# %%
c = cast
c = c[c.name == 'George Clooney']
c.groupby(['year']).size().plot(style='*', ylim=0, figsize=[12,6])

# %%
c = cast
c = c[c.name == 'George Clooney']
c.groupby([c.year // 10 * 10]).size() #groupings can be columns/calcs
# Out:
# year
# 1980     3
# 1990    14
# 2000    20
# 2010    10
# dtype: int64

# %%
c = cast
c.groupby([c.year // 10 * 10, c.type]).size()
# Out:
# year  type
# 1890  actor           2
#       actress         1
# 1900  actor          54
#       actress        16
# 1910  actor       27605
#       actress     15830
# 1920  actor       48726
#       actress     24075
# 1930  actor      151290
#       actress     49972
# 1940  actor      162364
#       actress     51795
# 1950  actor      157738
#       actress     57733
# 1960  actor      134605
#       actress     57744
# 1970  actor      152811
#       actress     66974
# 1980  actor      197530
#       actress     91509
# 1990  actor      263000
#       actress    125040
# 2000  actor      489468
#       actress    263941
# 2010  actor      747346
#       actress    448737
# 2020  actor         140
#       actress       127
# 2110  actor           2
#       actress         1
# dtype: int64

# %%
c = cast
c = c[(c.character == 'Kermit the Frog') 
      | (c.character == 'Oscar the Grouch')]
g = c.groupby(['character', c.year // 10 * 10]).size()
g
# Out:
# character         year
# Kermit the Frog   1970    1
#                   1980    4
#                   1990    2
#                   2000    1
#                   2010    1
# Oscar the Grouch  1980    2
#                   1990    1
#                   2000    1
# dtype: int64

# %%
u = g.unstack(0).fillna(0) #can control which columns you pivot in the brackets
u
# Out:
# character  Kermit the Frog  Oscar the Grouch
# year
# 1970                   1.0               0.0
# 1980                   4.0               2.0
# 1990                   2.0               1.0
# 2000                   1.0               1.0
# 2010                   1.0               0.0

# %%
u['Kermit the Frog'] - u['Oscar the Grouch']
# Out:
# year
# 1970    1.0
# 1980    2.0
# 1990    1.0
# 2000    0.0
# 2010    1.0
# dtype: float64

# %%
u.stack()
# Out:
# year  character
# 1970  Kermit the Frog     1.0
#       Oscar the Grouch    0.0
# 1980  Kermit the Frog     4.0
#       Oscar the Grouch    2.0
# 1990  Kermit the Frog     2.0
#       Oscar the Grouch    1.0
# 2000  Kermit the Frog     1.0
#       Oscar the Grouch    1.0
# 2010  Kermit the Frog     1.0
#       Oscar the Grouch    0.0
# dtype: float64

# %%
g
# Out:
# character         year
# Kermit the Frog   1970    1
#                   1980    4
#                   1990    2
#                   2000    1
#                   2010    1
# Oscar the Grouch  1980    2
#                   1990    1
#                   2000    1
# dtype: int64

# %%
df = g.unstack('character')
df['extra'] = 1
df = df.set_index('extra', drop=True, append=True)
df.unstack(0)
# Out:
# character Kermit the Frog                     Oscar the Grouch                 \
# year                 1970 1980 1990 2000 2010             1970 1980 1990 2000
# extra
# 1                     1.0  4.0  2.0  1.0  1.0              NaN  2.0  1.0  1.0
#
# character
# year      2010
# extra
# 1          NaN

# %%
df
# Out:
# character   Kermit the Frog  Oscar the Grouch
# year extra
# 1970 1                  1.0               NaN
# 1980 1                  4.0               2.0
# 1990 1                  2.0               1.0
# 2000 1                  1.0               1.0
# 2010 1                  1.0               NaN

# %%
df.reset_index('extra')
# Out:
# character  extra  Kermit the Frog  Oscar the Grouch
# year
# 1970           1              1.0               NaN
# 1980           1              4.0               2.0
# 1990           1              2.0               1.0
# 2000           1              1.0               1.0
# 2010           1              1.0               NaN

# %%
release_dates = pd.read_csv('data/release_dates.csv', index_col=None,
                                      parse_dates=['date'], infer_datetime_format=True)

# %%
r = release_dates
r.head()
# Out:
#                     title  year      country       date
# 0   #73, Shaanthi Nivaasa  2007        India 2007-06-15
# 1                   #BKKY  2016     Cambodia 2017-10-12
# 2                 #Beings  2015      Romania 2015-01-29
# 3               #Captured  2017          USA 2017-09-05
# 4  #Ewankosau saranghaeyo  2015  Philippines 2015-01-21

# %%
r.date.dt.year
# Out:
# 0         2007
# 1         2017
# 2         2015
# 3         2017
# 4         2015
# 5         2015
# 6         2016
# 7         2015
# 8         2014
# 9         2016
# 10        2017
# 11        2017
# 12        2018
# 13        2013
# 14        2014
# 15        2014
# 16        2016
# 17        2014
# 18        2015
# 19        2017
# 20        2018
# 21        1972
# 22        1972
# 23        1972
# 24        1972
# 25        1972
# 26        1972
# 27        1972
# 28        1972
# 29        1972
#           ...
# 479458    2005
# 479459    2005
# 479460    2005
# 479461    2005
# 479462    2005
# 479463    2005
# 479464    2005
# 479465    2005
# 479466    2005
# 479467    2005
# 479468    2005
# 479469    2005
# 479470    2005
# 479471    2005
# 479472    2005
# 479473    2005
# 479474    2005
# 479475    2005
# 479476    2005
# 479477    2005
# 479478    2005
# 479479    2005
# 479480    2005
# 479481    2005
# 479482    2005
# 479483    2005
# 479484    2005
# ...

# %%
# merge

# %%
c = cast[(cast.name == 'Ellen Page')]
c.merge(release_dates).sample(10)
# Out:
#                           title  year        name     type       character  \
# 516       X-Men: The Last Stand  2006  Ellen Page  actress       Shadowcat
# 199                        Juno  2007  Ellen Page  actress    Juno MacGuff
# 389  X-Men: Days of Future Past  2014  Ellen Page  actress     Kitty Pryde
# 113                   Inception  2010  Ellen Page  actress         Ariadne
# 312           To Rome with Love  2012  Ellen Page  actress          Monica
# 533       X-Men: The Last Stand  2006  Ellen Page  actress       Shadowcat
# 347                     Whip It  2009  Ellen Page  actress  Bliss Cavendar
# 419  X-Men: Days of Future Past  2014  Ellen Page  actress     Kitty Pryde
# 456       X-Men: The Last Stand  2006  Ellen Page  actress     Kitty Pryde
# 263                       Super  2010  Ellen Page  actress           Libby
#
#         n     country       date
# 516  13.0    Portugal 2006-05-25
# 199   1.0      Russia 2008-02-28
# 389   8.0      Kuwait 2014-05-22
# ...

# %%
# pivots

# %%
r = release_dates
r = r[(r.title.str.startswith('Star Wars: Episode'))]
r = r[(r.country.str.startswith('U'))]
# Out:
#                                              title  year  country       date
# 344361  Star Wars: Episode VII - The Force Awakens  2015      USA 2015-12-18
# 344412     Star Wars: Episode VIII - The Last Jedi  2017       UK 2017-12-14
# 344413     Star Wars: Episode VIII - The Last Jedi  2017  Ukraine 2017-12-14
# 344414     Star Wars: Episode VIII - The Last Jedi  2017  Uruguay 2017-12-14
# 344423     Star Wars: Episode VIII - The Last Jedi  2017      USA 2017-12-15

# %%
r.pivot('title', 'country', 'date') 
# pivots sets+sorts index, unstacks, and displays data
# Out:
# country                                                UK        USA  \
# title
# Star Wars: Episode I - The Phantom Menace      1999-07-15 1999-05-19
# Star Wars: Episode II - Attack of the Clones   2002-05-16 2002-05-16
# Star Wars: Episode III - Revenge of the Sith   2005-05-19 2005-05-19
# Star Wars: Episode IX                                 NaT 2019-12-20
# Star Wars: Episode V - The Empire Strikes Back 1980-05-21 1980-06-20
# Star Wars: Episode VI - Return of the Jedi     1983-06-02 1983-05-25
# Star Wars: Episode VII - The Force Awakens     2015-12-17 2015-12-18
# Star Wars: Episode VIII - The Last Jedi        2017-12-14 2017-12-15
#
# country                                           Ukraine  \
# title
# Star Wars: Episode I - The Phantom Menace             NaT
# Star Wars: Episode II - Attack of the Clones   2002-06-08
# Star Wars: Episode III - Revenge of the Sith          NaT
# Star Wars: Episode IX                                 NaT
# ...

# %%
c = cast
c = c[(c.n <= 2)]
c = c[(c.name == 'Cary Grant')]
c = c.merge(cast, on=['title','year'])
c = c[(c.n_y <=2)]
c = c[(c.name_y != 'Cary Grant')]
c
# Out:
#                                      title  year      name_x type_x  \
# 65                   An Affair to Remember  1957  Cary Grant  actor
# 110                   Arsenic and Old Lace  1944  Cary Grant  actor
# 161                         Big Brown Eyes  1936  Cary Grant  actor
# 213                         Born to Be Bad  1934  Cary Grant  actor
# 260                       Bringing Up Baby  1938  Cary Grant  actor
# 304                                Charade  1963  Cary Grant  actor
# 320                                 Crisis  1950  Cary Grant  actor
# 394                      Destination Tokyo  1943  Cary Grant  actor
# 515                             Dream Wife  1953  Cary Grant  actor
# 546                          Enter Madame!  1935  Cary Grant  actor
# 572           Every Girl Should Be Married  1948  Cary Grant  actor
# 608                           Father Goose  1964  Cary Grant  actor
# 640                          Gambling Ship  1933  Cary Grant  actor
# ...

# %%
sales1 = pd.read_csv('sales1.csv')
sales1
# Out:
#                          Book title  Number sold  Sales price  Royalty paid
# 0            The Bricklayer’s Bible            8         2.99          0.55
# 1                          Swimrand            2         1.99          0.35
# 2  Pining For The Fisheries of Yore           28         2.99          0.55
# 3                The Duck Goes Here           34         2.99          0.55
# 4       The Tower Commission Report            4        11.50          4.25

# %%
sales2 = pd.read_csv('sales2.csv')
sales2.fillna('')[:10]
# Out:
#                               Title Units sold List price Royalty
# 0
# 1               Sales report for Q4
# 2            E-Book Reader US Store
# 3  Pining for the Fisheries of Yore         80        3.5   14.98
# 4                          Swimrand          1       2.99    0.14
# 5            The Bricklayer's Bible         17        3.5    5.15
# 6                The Duck Goes Here         34       2.99    5.78
# 7       The Tower Commission Report          4        9.5     6.2
# 8                US royalties (USD)                         32.25
# 9

# %%
col = sales2.Title.str.extract(r'\((.*)\)')
sales2['Currency'] = col.fillna(method='bfill')
sales2
# Out:
#                                Title  Units sold  List price  Royalty Currency
# 0                                NaN         NaN         NaN      NaN      USD
# 1                Sales report for Q4         NaN         NaN      NaN      USD
# 2             E-Book Reader US Store         NaN         NaN      NaN      USD
# 3   Pining for the Fisheries of Yore        80.0        3.50    14.98      USD
# 4                           Swimrand         1.0        2.99     0.14      USD
# 5             The Bricklayer's Bible        17.0        3.50     5.15      USD
# 6                 The Duck Goes Here        34.0        2.99     5.78      USD
# 7        The Tower Commission Report         4.0        9.50     6.20      USD
# 8                 US royalties (USD)         NaN         NaN    32.25      USD
# 9                                NaN         NaN         NaN      NaN      GBP
# 10                               NaN         NaN         NaN      NaN      GBP
# ...
